# %%
from __future__ import print_function
import pandas as pd
# As usual, a bit of setup
import time
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

filename='result6.csv'

# Load the CSV file into a DataFrame
df = pd.read_csv(filename)

# Assuming 'x' and 'lr0' are columns in the CSV file
# Calculate 'x/lr0' and plot it
#if 'x/lr0' in df.columns:
    # Avoid division by zero

plt.figure(figsize=(10, 5))
plt.plot(df['               x/lr0'], label='lr0')
plt.plot(df['               x/lr1'], 'o', label='lr1')
plt.plot(df['               x/lr2'], label='lr2')
plt.title('lr over epochs')
plt.xlabel('Epoch')
plt.ylabel('lr')
plt.legend()
plt.grid(True)
plt.show()
#else:
#    print("The required columns 'x' or 'lr0' do not exist in the CSV file.")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Let's attempt to read the CSV file and plot the mAP and loss data.
# First, we need to load the CSV file.

df = pd.read_csv(filename)

# Now, we'll try to plot the mAP and loss values.
# We're assuming the columns are named in a standard way such as 'mAP', 'loss', etc.

# Check if the 'mAP' column exists and plot it.
#if 'mAP' in df.columns:
# plt.plot(df['mAP'], label='mAP')

# Check for loss columns. We assume they may be named 'loss', 'val_loss', etc.
#loss_cols = [col for col in df.columns if 'loss' in col.lower()]
#for col in loss_cols:

plt.plot(df['     metrics/mAP_0.5'], label='     metrics/mAP_0.5')
plt.plot(df['metrics/mAP_0.5:0.95'], label='metrics/mAP_0.5:0.95')
plt.title('mAP and Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
df = pd.read_csv(filename)


plt.subplots(1, 3, figsize=(20, 5))
plt.subplot(1,3,1)
plt.plot(df['      train/box_loss'], label='      train/box_loss')
plt.plot(df['        val/box_loss'], label='        val/box_loss')
plt.title('box losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()


plt.subplot(1,3,2)
plt.plot(df['      train/obj_loss'], label='      train/obj_loss')
plt.plot(df['        val/obj_loss'], label='        val/obj_loss')
plt.title('obj losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()


plt.subplot(1,3,3)
plt.plot(df['      train/cls_loss'], label='      train/cls_loss')
plt.plot(df['        val/cls_loss'], label='        val/cls_loss')
plt.title('cls losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')


plt.legend()
plt.grid(True)
plt.show()
